# %%
import pandas as pd

# %%
! ls - la datos

# %%
! cat datos/clientes.csv

# %%
df_clientes = pd.read_csv(datos/clientes.csv)
df_clientes.info()
# Out:
#   Cell In[8], line 1
#     df_clientes = pd.read_csv(C:\Users\valer\OneDrive\Escritorio\datos\clientes.csv)
#                                ^
# SyntaxError: invalid syntax

# %%
df_clientes

# %%
df_facturas=pd.read_csv("datos/facturas.csv", sep='|')
df_facturas

# %%
df_players =pd.read_csv("https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/jugadores.csv")
df_players
# Out:
#                  Name Team        Position  Height(inches)  Weight(pounds)  \
# 0       Adam_Donachie  BAL         Catcher              74             180
# 1           Paul_Bako  BAL         Catcher              74             215
# 2     Ramon_Hernandez  BAL         Catcher              72             210
# 3        Kevin_Millar  BAL   First_Baseman              72             210
# 4         Chris_Gomez  BAL   First_Baseman              73             188
# ...               ...  ...             ...             ...             ...
# 1029    Brad_Thompson  STL  Relief_Pitcher              73             190
# 1030    Tyler_Johnson  STL  Relief_Pitcher              74             180
# 1031   Chris_Narveson  STL  Relief_Pitcher              75             205
# 1032    Randy_Keisler  STL  Relief_Pitcher              75             190
# 1033      Josh_Kinney  STL  Relief_Pitcher              73             195
#
#         Age
# 0     22.99
# 1     34.69
# 2     30.78
# 3     35.43
# ...

# %%
df_players.head()
# Out:
#               Name Team       Position  Height(inches)  Weight(pounds)    Age
# 0    Adam_Donachie  BAL        Catcher              74             180  22.99
# 1        Paul_Bako  BAL        Catcher              74             215  34.69
# 2  Ramon_Hernandez  BAL        Catcher              72             210  30.78
# 3     Kevin_Millar  BAL  First_Baseman              72             210  35.43
# 4      Chris_Gomez  BAL  First_Baseman              73             188  35.71

# %%
df_players.tail()
# Out:
#                 Name Team        Position  Height(inches)  Weight(pounds)  \
# 1029   Brad_Thompson  STL  Relief_Pitcher              73             190
# 1030   Tyler_Johnson  STL  Relief_Pitcher              74             180
# 1031  Chris_Narveson  STL  Relief_Pitcher              75             205
# 1032   Randy_Keisler  STL  Relief_Pitcher              75             190
# 1033     Josh_Kinney  STL  Relief_Pitcher              73             195
#
#         Age
# 1029  25.08
# 1030  25.73
# 1031  25.19
# 1032  31.01
# 1033  27.92

# %%
df_players.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Height(inches)', 'Weight(pounds)', 'Age'], dtype='object')

# %%
columnas = ['Nombre','Equipo','Posicion','Altura','Peso','Edad']
df_jugadores =pd.read_csv("https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/jugadores.csv",names=columnas, header= None, skiprows=1)
df_jugadores
# Out:
#                Nombre Equipo        Posicion  Altura  Peso   Edad
# 0       Adam_Donachie    BAL         Catcher      74   180  22.99
# 1           Paul_Bako    BAL         Catcher      74   215  34.69
# 2     Ramon_Hernandez    BAL         Catcher      72   210  30.78
# 3        Kevin_Millar    BAL   First_Baseman      72   210  35.43
# 4         Chris_Gomez    BAL   First_Baseman      73   188  35.71
# ...               ...    ...             ...     ...   ...    ...
# 1029    Brad_Thompson    STL  Relief_Pitcher      73   190  25.08
# 1030    Tyler_Johnson    STL  Relief_Pitcher      74   180  25.73
# 1031   Chris_Narveson    STL  Relief_Pitcher      75   205  25.19
# 1032    Randy_Keisler    STL  Relief_Pitcher      75   190  31.01
# 1033      Josh_Kinney    STL  Relief_Pitcher      73   195  27.92
#
# [1034 rows x 6 columns]

# %%
df_json_url=pd.read_json("https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/iris.json")
df_json_url
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df_json_url=pd.read_json("https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/iris.json")
#       2 df_json_url
#
# TypeError: 'str' object is not callable

# %%
df_alumnos= pd.read_json=("datos/alumnos")
df_alumnos
# Out:
# 'datos/alumnos'

# %%
df_carrera =pd.read_excel('datos/carrera.xlsx', sheet_name="BdCarrera2022", header= None, names=['MATRICULA', 'SEDE', 'NOMBRE', 'EDAD', 'SEXO', 'NACIONALIDAD', 'ESTADO_CIVIL', 'MODALIDAD', 'PROM_PSU', 'PROM_NEM', 'SITUACION_ECONOMICA', 'ESTADO', 'CALIFICACION', 'CURSO'])
df_carrera
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df_carrera =pd.read_excel('datos/carrera.xlsx', sheet_name="BdCarrera2022", header= None, names=['MATRICULA', 'SEDE', 'NOMBRE', 'EDAD', 'SEXO', 'NACIONALIDAD', 'ESTADO_CIVIL', 'MODALIDAD', 'PROM_PSU', 'PROM_NEM', 'SITUACION_ECONOMICA', 'ESTADO', 'CALIFICACION', 'CURSO'])
#       2 df_carrera
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...
